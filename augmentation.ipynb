# %%
import cv2
import os


def augment_video(input_path, output_dir):
    """Augment a single video and save augmented versions."""
    cap = cv2.VideoCapture(input_path)
    if not cap.isOpened():
        print(f"Error opening video file: {input_path}")
        return

    # Video properties
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    codec = cv2.VideoWriter_fourcc(*'mp4v')

    # Define augmentations
    augmentations = {
        "original": lambda frame: frame,
        "flip_horizontal": lambda frame: cv2.flip(frame, 1),
        "flip_vertical": lambda frame: cv2.flip(frame, 0),
        "rotate_90": lambda frame: cv2.rotate(frame, cv2.ROTATE_90_CLOCKWISE),
        "rotate_180": lambda frame: cv2.rotate(frame, cv2.ROTATE_180),
        "rotate_270": lambda frame: cv2.rotate(frame, cv2.ROTATE_90_COUNTERCLOCKWISE)
    }

    for name, func in augmentations.items():
        # Handle rotated dimensions
        out_width, out_height = (height, width) if 'rotate' in name else (width, height)

        # Prepare output path and writer
        video_name = os.path.splitext(os.path.basename(input_path))[0]
        output_path = os.path.join(output_dir, f"{video_name}_{name}.mp4")
        out = cv2.VideoWriter(output_path, codec, fps, (out_width, out_height))

        cap.set(cv2.CAP_PROP_POS_FRAMES, 0)  # Reset frame position

        while True:
            ret, frame = cap.read()
            if not ret:
                break
            augmented_frame = func(frame)
            out.write(augmented_frame)

        out.release()
        print(f"Saved: {output_path}")

    cap.release()


def process_videos_from_folder(input_folder, output_folder):
    """Process all video files in a folder."""
    os.makedirs(output_folder, exist_ok=True)
    video_extensions = (".mp4", ".avi", ".mov", ".mkv")

    video_files = [file for file in os.listdir(input_folder) if file.lower().endswith(video_extensions)]

    if not video_files:
        print("No video files found in the input folder.")
        return

    for video_file in video_files:
        input_path = os.path.join(input_folder, video_file)
        print(f"Processing: {video_file}")
        augment_video(input_path, output_folder)


# Usage Example
input_folder = r"C:\Users\arman\Desktop\Rope-detection-v3\Dataset\consent"       # Replace with your input folder path
output_folder = "consent-augmented_videos"  # Folder to save augmented videos
process_videos_from_folder(input_folder, output_folder)
# Out:
# Processing: consent_1.mp4
# Saved: consent-augmented_videos\consent_1_original.mp4
# Saved: consent-augmented_videos\consent_1_flip_horizontal.mp4
# Saved: consent-augmented_videos\consent_1_flip_vertical.mp4
# Saved: consent-augmented_videos\consent_1_rotate_90.mp4
# Saved: consent-augmented_videos\consent_1_rotate_180.mp4
# Saved: consent-augmented_videos\consent_1_rotate_270.mp4
# Processing: consent_10.mp4
# Saved: consent-augmented_videos\consent_10_original.mp4
# Saved: consent-augmented_videos\consent_10_flip_horizontal.mp4
# Saved: consent-augmented_videos\consent_10_flip_vertical.mp4
# Saved: consent-augmented_videos\consent_10_rotate_90.mp4
# Saved: consent-augmented_videos\consent_10_rotate_180.mp4
# Saved: consent-augmented_videos\consent_10_rotate_270.mp4
# Processing: consent_11.mp4
# Saved: consent-augmented_videos\consent_11_original.mp4
# Saved: consent-augmented_videos\consent_11_flip_horizontal.mp4
# Saved: consent-augmented_videos\consent_11_flip_vertical.mp4
# Saved: consent-augmented_videos\consent_11_rotate_90.mp4
# Saved: consent-augmented_videos\consent_11_rotate_180.mp4
# Saved: consent-augmented_videos\consent_11_rotate_270.mp4
# Processing: consent_12.mp4
# Saved: consent-augmented_videos\consent_12_original.mp4
# Saved: consent-augmented_videos\consent_12_flip_horizontal.mp4
# Saved: consent-augmented_videos\consent_12_flip_vertical.mp4
# Saved: consent-augmented_videos\consent_12_rotate_90.mp4
# Saved: consent-augmented_videos\consent_12_rotate_180.mp4
# Saved: consent-augmented_videos\consent_12_rotate_270.mp4
# Processing: consent_13.mp4
# Saved: consent-augmented_videos\consent_13_original.mp4
# Saved: consent-augmented_videos\consent_13_flip_horizontal.mp4
# Saved: consent-augmented_videos\consent_13_flip_vertical.mp4
# Saved: consent-augmented_videos\consent_13_rotate_90.mp4
# Saved: consent-augmented_videos\consent_13_rotate_180.mp4
# Saved: consent-augmented_videos\consent_13_rotate_270.mp4
# Processing: consent_14.mp4
# Saved: consent-augmented_videos\consent_14_original.mp4
# Saved: consent-augmented_videos\consent_14_flip_horizontal.mp4
# Saved: consent-augmented_videos\consent_14_flip_vertical.mp4
# Saved: consent-augmented_videos\consent_14_rotate_90.mp4
# Saved: consent-augmented_videos\consent_14_rotate_180.mp4
# Saved: consent-augmented_videos\consent_14_rotate_270.mp4
# Processing: consent_15.mp4
# Saved: consent-augmented_videos\consent_15_original.mp4
# Saved: consent-augmented_videos\consent_15_flip_horizontal.mp4
# Saved: consent-augmented_videos\consent_15_flip_vertical.mp4
# Saved: consent-augmented_videos\consent_15_rotate_90.mp4
# Saved: consent-augmented_videos\consent_15_rotate_180.mp4
# Saved: consent-augmented_videos\consent_15_rotate_270.mp4
# Processing: consent_16.mp4
# Saved: consent-augmented_videos\consent_16_original.mp4
# Saved: consent-augmented_videos\consent_16_flip_horizontal.mp4
# Saved: consent-augmented_videos\consent_16_flip_vertical.mp4
# Saved: consent-augmented_videos\consent_16_rotate_90.mp4
# Saved: consent-augmented_videos\consent_16_rotate_180.mp4
# Saved: consent-augmented_videos\consent_16_rotate_270.mp4
# Processing: consent_17.mp4
# Saved: consent-augmented_videos\consent_17_original.mp4
# Saved: consent-augmented_videos\consent_17_flip_horizontal.mp4
# Saved: consent-augmented_videos\consent_17_flip_vertical.mp4
# Saved: consent-augmented_videos\consent_17_rotate_90.mp4
# Saved: consent-augmented_videos\consent_17_rotate_180.mp4
# Saved: consent-augmented_videos\consent_17_rotate_270.mp4
# Processing: consent_18.mp4
# Saved: consent-augmented_videos\consent_18_original.mp4
# Saved: consent-augmented_videos\consent_18_flip_horizontal.mp4
# Saved: consent-augmented_videos\consent_18_flip_vertical.mp4
# Saved: consent-augmented_videos\consent_18_rotate_90.mp4
# Saved: consent-augmented_videos\consent_18_rotate_180.mp4
# Saved: consent-augmented_videos\consent_18_rotate_270.mp4
# Processing: consent_19.mp4
# Saved: consent-augmented_videos\consent_19_original.mp4
# Saved: consent-augmented_videos\consent_19_flip_horizontal.mp4
# Saved: consent-augmented_videos\consent_19_flip_vertical.mp4
# Saved: consent-augmented_videos\consent_19_rotate_90.mp4
# Saved: consent-augmented_videos\consent_19_rotate_180.mp4
# Saved: consent-augmented_videos\consent_19_rotate_270.mp4
# Processing: consent_2.mp4
# Saved: consent-augmented_videos\consent_2_original.mp4
# Saved: consent-augmented_videos\consent_2_flip_horizontal.mp4
# Saved: consent-augmented_videos\consent_2_flip_vertical.mp4
# Saved: consent-augmented_videos\consent_2_rotate_90.mp4
# Saved: consent-augmented_videos\consent_2_rotate_180.mp4
# Saved: consent-augmented_videos\consent_2_rotate_270.mp4
# Processing: consent_20.mp4
# Saved: consent-augmented_videos\consent_20_original.mp4
# Saved: consent-augmented_videos\consent_20_flip_horizontal.mp4
# Saved: consent-augmented_videos\consent_20_flip_vertical.mp4
# Saved: consent-augmented_videos\consent_20_rotate_90.mp4
# Saved: consent-augmented_videos\consent_20_rotate_180.mp4
# Saved: consent-augmented_videos\consent_20_rotate_270.mp4
# Processing: consent_3.mp4
# Saved: consent-augmented_videos\consent_3_original.mp4
# Saved: consent-augmented_videos\consent_3_flip_horizontal.mp4
# Saved: consent-augmented_videos\consent_3_flip_vertical.mp4
# Saved: consent-augmented_videos\consent_3_rotate_90.mp4
# Saved: consent-augmented_videos\consent_3_rotate_180.mp4
# Saved: consent-augmented_videos\consent_3_rotate_270.mp4
# Processing: consent_4.mp4
# Saved: consent-augmented_videos\consent_4_original.mp4
# Saved: consent-augmented_videos\consent_4_flip_horizontal.mp4
# Saved: consent-augmented_videos\consent_4_flip_vertical.mp4
# Saved: consent-augmented_videos\consent_4_rotate_90.mp4
# Saved: consent-augmented_videos\consent_4_rotate_180.mp4
# Saved: consent-augmented_videos\consent_4_rotate_270.mp4
# Processing: consent_5.mp4
# Saved: consent-augmented_videos\consent_5_original.mp4
# Saved: consent-augmented_videos\consent_5_flip_horizontal.mp4
# Saved: consent-augmented_videos\consent_5_flip_vertical.mp4
# Saved: consent-augmented_videos\consent_5_rotate_90.mp4
# Saved: consent-augmented_videos\consent_5_rotate_180.mp4
# Saved: consent-augmented_videos\consent_5_rotate_270.mp4
# Processing: consent_6.mp4
# Saved: consent-augmented_videos\consent_6_original.mp4
# Saved: consent-augmented_videos\consent_6_flip_horizontal.mp4
# Saved: consent-augmented_videos\consent_6_flip_vertical.mp4
# Saved: consent-augmented_videos\consent_6_rotate_90.mp4
# Saved: consent-augmented_videos\consent_6_rotate_180.mp4
# Saved: consent-augmented_videos\consent_6_rotate_270.mp4
# Processing: consent_7.mp4
# Saved: consent-augmented_videos\consent_7_original.mp4
# Saved: consent-augmented_videos\consent_7_flip_horizontal.mp4
# Saved: consent-augmented_videos\consent_7_flip_vertical.mp4
# Saved: consent-augmented_videos\consent_7_rotate_90.mp4
# Saved: consent-augmented_videos\consent_7_rotate_180.mp4
# Saved: consent-augmented_videos\consent_7_rotate_270.mp4
# Processing: consent_8.mp4
# Saved: consent-augmented_videos\consent_8_original.mp4
# Saved: consent-augmented_videos\consent_8_flip_horizontal.mp4
# Saved: consent-augmented_videos\consent_8_flip_vertical.mp4
# Saved: consent-augmented_videos\consent_8_rotate_90.mp4
# Saved: consent-augmented_videos\consent_8_rotate_180.mp4
# Saved: consent-augmented_videos\consent_8_rotate_270.mp4
# Processing: consent_9.mp4
# Saved: consent-augmented_videos\consent_9_original.mp4
# Saved: consent-augmented_videos\consent_9_flip_horizontal.mp4
# Saved: consent-augmented_videos\consent_9_flip_vertical.mp4
# Saved: consent-augmented_videos\consent_9_rotate_90.mp4
# Saved: consent-augmented_videos\consent_9_rotate_180.mp4
# Saved: consent-augmented_videos\consent_9_rotate_270.mp4

# %%
import cv2
import os


def augment_video(input_path, output_dir):
    """Augment a single video and save augmented versions."""
    cap = cv2.VideoCapture(input_path)
    if not cap.isOpened():
        print(f"Error opening video file: {input_path}")
        return

    # Video properties
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    codec = cv2.VideoWriter_fourcc(*'mp4v')

    # Define augmentations
    augmentations = {
        "original": lambda frame: frame,
        "flip_horizontal": lambda frame: cv2.flip(frame, 1),
        "flip_vertical": lambda frame: cv2.flip(frame, 0),
        "rotate_90": lambda frame: cv2.rotate(frame, cv2.ROTATE_90_CLOCKWISE),
        "rotate_180": lambda frame: cv2.rotate(frame, cv2.ROTATE_180),
        "rotate_270": lambda frame: cv2.rotate(frame, cv2.ROTATE_90_COUNTERCLOCKWISE)
    }

    for name, func in augmentations.items():
        # Handle rotated dimensions
        out_width, out_height = (height, width) if 'rotate' in name else (width, height)

        # Prepare output path and writer
        video_name = os.path.splitext(os.path.basename(input_path))[0]
        output_path = os.path.join(output_dir, f"{video_name}_{name}.mp4")
        out = cv2.VideoWriter(output_path, codec, fps, (out_width, out_height))

        cap.set(cv2.CAP_PROP_POS_FRAMES, 0)  # Reset frame position

        while True:
            ret, frame = cap.read()
            if not ret:
                break
            augmented_frame = func(frame)
            out.write(augmented_frame)

        out.release()
        print(f"Saved: {output_path}")

    cap.release()


def process_videos_from_folder(input_folder, output_folder):
    """Process all video files in a folder."""
    os.makedirs(output_folder, exist_ok=True)
    video_extensions = (".mp4", ".avi", ".mov", ".mkv")

    video_files = [file for file in os.listdir(input_folder) if file.lower().endswith(video_extensions)]

    if not video_files:
        print("No video files found in the input folder.")
        return

    for video_file in video_files:
        input_path = os.path.join(input_folder, video_file)
        print(f"Processing: {video_file}")
        augment_video(input_path, output_folder)


# Usage Example
input_folder = r"C:\Users\arman\Desktop\Rope-detection-v3\Dataset\nonconsent"       # Replace with your input folder path
output_folder = "non-consent-augmented_videos"  # Folder to save augmented videos
process_videos_from_folder(input_folder, output_folder)
# Out:
# Processing: non-consent_1.mp4
# Saved: non-consent-augmented_videos\non-consent_1_original.mp4
# Saved: non-consent-augmented_videos\non-consent_1_flip_horizontal.mp4
# Saved: non-consent-augmented_videos\non-consent_1_flip_vertical.mp4
# Saved: non-consent-augmented_videos\non-consent_1_rotate_90.mp4
# Saved: non-consent-augmented_videos\non-consent_1_rotate_180.mp4
# Saved: non-consent-augmented_videos\non-consent_1_rotate_270.mp4
# Processing: non-consent_10.mp4
# Saved: non-consent-augmented_videos\non-consent_10_original.mp4
# Saved: non-consent-augmented_videos\non-consent_10_flip_horizontal.mp4
# Saved: non-consent-augmented_videos\non-consent_10_flip_vertical.mp4
# Saved: non-consent-augmented_videos\non-consent_10_rotate_90.mp4
# Saved: non-consent-augmented_videos\non-consent_10_rotate_180.mp4
# Saved: non-consent-augmented_videos\non-consent_10_rotate_270.mp4
# Processing: non-consent_11.mp4
# Saved: non-consent-augmented_videos\non-consent_11_original.mp4
# Saved: non-consent-augmented_videos\non-consent_11_flip_horizontal.mp4
# Saved: non-consent-augmented_videos\non-consent_11_flip_vertical.mp4
# Saved: non-consent-augmented_videos\non-consent_11_rotate_90.mp4
# Saved: non-consent-augmented_videos\non-consent_11_rotate_180.mp4
# Saved: non-consent-augmented_videos\non-consent_11_rotate_270.mp4
# Processing: non-consent_12.mp4
# Saved: non-consent-augmented_videos\non-consent_12_original.mp4
# Saved: non-consent-augmented_videos\non-consent_12_flip_horizontal.mp4
# Saved: non-consent-augmented_videos\non-consent_12_flip_vertical.mp4
# Saved: non-consent-augmented_videos\non-consent_12_rotate_90.mp4
# Saved: non-consent-augmented_videos\non-consent_12_rotate_180.mp4
# Saved: non-consent-augmented_videos\non-consent_12_rotate_270.mp4
# Processing: non-consent_13.mp4
# Saved: non-consent-augmented_videos\non-consent_13_original.mp4
# Saved: non-consent-augmented_videos\non-consent_13_flip_horizontal.mp4
# Saved: non-consent-augmented_videos\non-consent_13_flip_vertical.mp4
# Saved: non-consent-augmented_videos\non-consent_13_rotate_90.mp4
# Saved: non-consent-augmented_videos\non-consent_13_rotate_180.mp4
# Saved: non-consent-augmented_videos\non-consent_13_rotate_270.mp4
# Processing: non-consent_14.mp4
# Saved: non-consent-augmented_videos\non-consent_14_original.mp4
# Saved: non-consent-augmented_videos\non-consent_14_flip_horizontal.mp4
# Saved: non-consent-augmented_videos\non-consent_14_flip_vertical.mp4
# Saved: non-consent-augmented_videos\non-consent_14_rotate_90.mp4
# Saved: non-consent-augmented_videos\non-consent_14_rotate_180.mp4
# Saved: non-consent-augmented_videos\non-consent_14_rotate_270.mp4
# Processing: non-consent_15.mp4
# Saved: non-consent-augmented_videos\non-consent_15_original.mp4
# Saved: non-consent-augmented_videos\non-consent_15_flip_horizontal.mp4
# Saved: non-consent-augmented_videos\non-consent_15_flip_vertical.mp4
# Saved: non-consent-augmented_videos\non-consent_15_rotate_90.mp4
# Saved: non-consent-augmented_videos\non-consent_15_rotate_180.mp4
# Saved: non-consent-augmented_videos\non-consent_15_rotate_270.mp4
# Processing: non-consent_16.mp4
# Saved: non-consent-augmented_videos\non-consent_16_original.mp4
# Saved: non-consent-augmented_videos\non-consent_16_flip_horizontal.mp4
# Saved: non-consent-augmented_videos\non-consent_16_flip_vertical.mp4
# Saved: non-consent-augmented_videos\non-consent_16_rotate_90.mp4
# Saved: non-consent-augmented_videos\non-consent_16_rotate_180.mp4
# Saved: non-consent-augmented_videos\non-consent_16_rotate_270.mp4
# Processing: non-consent_17.mp4
# Saved: non-consent-augmented_videos\non-consent_17_original.mp4
# Saved: non-consent-augmented_videos\non-consent_17_flip_horizontal.mp4
# Saved: non-consent-augmented_videos\non-consent_17_flip_vertical.mp4
# Saved: non-consent-augmented_videos\non-consent_17_rotate_90.mp4
# Saved: non-consent-augmented_videos\non-consent_17_rotate_180.mp4
# Saved: non-consent-augmented_videos\non-consent_17_rotate_270.mp4
# Processing: non-consent_18.mp4
# Saved: non-consent-augmented_videos\non-consent_18_original.mp4
# Saved: non-consent-augmented_videos\non-consent_18_flip_horizontal.mp4
# Saved: non-consent-augmented_videos\non-consent_18_flip_vertical.mp4
# Saved: non-consent-augmented_videos\non-consent_18_rotate_90.mp4
# Saved: non-consent-augmented_videos\non-consent_18_rotate_180.mp4
# Saved: non-consent-augmented_videos\non-consent_18_rotate_270.mp4
# Processing: non-consent_19.mp4
# Saved: non-consent-augmented_videos\non-consent_19_original.mp4
# Saved: non-consent-augmented_videos\non-consent_19_flip_horizontal.mp4
# Saved: non-consent-augmented_videos\non-consent_19_flip_vertical.mp4
# Saved: non-consent-augmented_videos\non-consent_19_rotate_90.mp4
# Saved: non-consent-augmented_videos\non-consent_19_rotate_180.mp4
# Saved: non-consent-augmented_videos\non-consent_19_rotate_270.mp4
# Processing: non-consent_2.mp4
# Saved: non-consent-augmented_videos\non-consent_2_original.mp4
# Saved: non-consent-augmented_videos\non-consent_2_flip_horizontal.mp4
# Saved: non-consent-augmented_videos\non-consent_2_flip_vertical.mp4
# Saved: non-consent-augmented_videos\non-consent_2_rotate_90.mp4
# Saved: non-consent-augmented_videos\non-consent_2_rotate_180.mp4
# Saved: non-consent-augmented_videos\non-consent_2_rotate_270.mp4
# Processing: non-consent_20.mp4
# Saved: non-consent-augmented_videos\non-consent_20_original.mp4
# Saved: non-consent-augmented_videos\non-consent_20_flip_horizontal.mp4
# Saved: non-consent-augmented_videos\non-consent_20_flip_vertical.mp4
# Saved: non-consent-augmented_videos\non-consent_20_rotate_90.mp4
# Saved: non-consent-augmented_videos\non-consent_20_rotate_180.mp4
# Saved: non-consent-augmented_videos\non-consent_20_rotate_270.mp4
# Processing: non-consent_3.mp4
# Saved: non-consent-augmented_videos\non-consent_3_original.mp4
# Saved: non-consent-augmented_videos\non-consent_3_flip_horizontal.mp4
# Saved: non-consent-augmented_videos\non-consent_3_flip_vertical.mp4
# Saved: non-consent-augmented_videos\non-consent_3_rotate_90.mp4
# Saved: non-consent-augmented_videos\non-consent_3_rotate_180.mp4
# Saved: non-consent-augmented_videos\non-consent_3_rotate_270.mp4
# Processing: non-consent_4.mp4
# Saved: non-consent-augmented_videos\non-consent_4_original.mp4
# Saved: non-consent-augmented_videos\non-consent_4_flip_horizontal.mp4
# Saved: non-consent-augmented_videos\non-consent_4_flip_vertical.mp4
# Saved: non-consent-augmented_videos\non-consent_4_rotate_90.mp4
# Saved: non-consent-augmented_videos\non-consent_4_rotate_180.mp4
# Saved: non-consent-augmented_videos\non-consent_4_rotate_270.mp4
# Processing: non-consent_5.mp4
# Saved: non-consent-augmented_videos\non-consent_5_original.mp4
# Saved: non-consent-augmented_videos\non-consent_5_flip_horizontal.mp4
# Saved: non-consent-augmented_videos\non-consent_5_flip_vertical.mp4
# Saved: non-consent-augmented_videos\non-consent_5_rotate_90.mp4
# Saved: non-consent-augmented_videos\non-consent_5_rotate_180.mp4
# Saved: non-consent-augmented_videos\non-consent_5_rotate_270.mp4
# Processing: non-consent_6.mp4
# Saved: non-consent-augmented_videos\non-consent_6_original.mp4
# Saved: non-consent-augmented_videos\non-consent_6_flip_horizontal.mp4
# Saved: non-consent-augmented_videos\non-consent_6_flip_vertical.mp4
# Saved: non-consent-augmented_videos\non-consent_6_rotate_90.mp4
# Saved: non-consent-augmented_videos\non-consent_6_rotate_180.mp4
# Saved: non-consent-augmented_videos\non-consent_6_rotate_270.mp4
# Processing: non-consent_7.mp4
# Saved: non-consent-augmented_videos\non-consent_7_original.mp4
# Saved: non-consent-augmented_videos\non-consent_7_flip_horizontal.mp4
# Saved: non-consent-augmented_videos\non-consent_7_flip_vertical.mp4
# Saved: non-consent-augmented_videos\non-consent_7_rotate_90.mp4
# Saved: non-consent-augmented_videos\non-consent_7_rotate_180.mp4
# Saved: non-consent-augmented_videos\non-consent_7_rotate_270.mp4
# Processing: non-consent_8.mp4
# Saved: non-consent-augmented_videos\non-consent_8_original.mp4
# Saved: non-consent-augmented_videos\non-consent_8_flip_horizontal.mp4
# Saved: non-consent-augmented_videos\non-consent_8_flip_vertical.mp4
# Saved: non-consent-augmented_videos\non-consent_8_rotate_90.mp4
# Saved: non-consent-augmented_videos\non-consent_8_rotate_180.mp4
# Saved: non-consent-augmented_videos\non-consent_8_rotate_270.mp4
# Processing: non-consent_9.mp4
# Saved: non-consent-augmented_videos\non-consent_9_original.mp4
# Saved: non-consent-augmented_videos\non-consent_9_flip_horizontal.mp4
# Saved: non-consent-augmented_videos\non-consent_9_flip_vertical.mp4
# Saved: non-consent-augmented_videos\non-consent_9_rotate_90.mp4
# Saved: non-consent-augmented_videos\non-consent_9_rotate_180.mp4
# Saved: non-consent-augmented_videos\non-consent_9_rotate_270.mp4
